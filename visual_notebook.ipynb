# %%
from main.preprocess import *

# %%
a = Global()

# %%
# mean_arrive=50.0, mean_serve=70.0, num_custom=20, max_queue=5, num_service=1
a.task_simulate(50.0, 70.0, 50, 10, 1)
# Out:
# [REPORT] 12(0.240) customers leave due to overflow of queue.
# [REPORT] average service process for served customers is 75.786464

# %%
# mean_arrive=50.0, mean_serve=50.0, num_custom=100, max_queue=20, num_service=1
a.task_simulate(50.0, 50.0, 1000, 200, 1)
# Out:
# [REPORT] 1(0.001) customers leave due to overflow of queue.
# [REPORT] average service process for served customers is 48.547394

# %%
# mean_arrive=50.0, mean_serve=50.0, num_custom=100, max_queue=20, num_service=1
a.task_simulate(50.0, 50.0, 1000, 200, 1)
# Out:
# [REPORT] 1(0.001) customers leave due to overflow of queue.
# [REPORT] average service process for served customers is 48.066271

# %%
# mean_arrive=50.0, mean_serve=50.0, num_custom=100, max_queue=20, num_service=1
a.task_simulate(50.0, 50.0, 1000, 200, 1)
# Out:
# [REPORT] 1(0.001) customers leave due to overflow of queue.
# [REPORT] average service process for served customers is 54.931356

# %%
# mean_arrive=50.0, mean_serve=50.0, num_custom=100, max_queue=20, num_service=1
a.task_simulate(5.0, 5.0, 1000, 200, 2)
# Out:
# [REPORT] 1(0.001) customers leave due to overflow of queue.
# [REPORT] average service process for served customers is 5.394708

# %%
# mean_arrive=50.0, mean_serve=50.0, num_custom=100, max_queue=20, num_service=1
a.task_simulate(50.0, 50.0, 1000, 200, 3)
# Out:
# [REPORT] 1(0.001) customers leave due to overflow of queue.
# [REPORT] average service process for served customers is 49.391316

# %%
# mean_arrive=50.0, mean_serve=50.0, num_custom=100, max_queue=20, num_service=1
a.task_simulate(50.0, 50.0, 1000, 200, 4)
# Out:
# [REPORT] 1(0.001) customers leave due to overflow of queue.
# [REPORT] average service process for served customers is 47.088130

# %%
# mean_arrive=50.0, mean_serve=100.0, num_custom=10000, max_queue=1000, num_service=1
service_mean_list = np.arange(50.0, 100.0, 1)
a.task_parameter_of_service_mean(50.0, service_mean_list, 10000, 1000, 1)

# %%
# mean_arrive=50.0, mean_serve=100.0, num_custom=10000, max_queue=1000, num_service=1
# internal_mean_list = np.arange(50.0, 100.0, 1)
# a.task_parameter_of_arrival_mean(service_mean_list, 100.0,10000, 1000, 1)

# %%
# mean_arrive=10.0, mean_serve=100.0, num_custom=10000, max_queue=1000, num_service=1
service_list = range(1,10,1)
queue_size_list = range(500,2000,50)
a.task_parameter_of_queue_size(10, 100.0,10000, queue_size_list, service_list)

# %%
# mean_arrive=10.0, mean_serve=100.0, num_custom=10000, max_queue=1000, num_service=1
service_list = range(1,10,1)
service_mean_list = range(50,200,10)
a.task_parameter_of_service_mean(10, service_mean_list,10000, 1000, service_list)

# %%
# mean_arrive=50.0, mean_serve=50.0, num_custom=100, max_queue=20, num_service=1
a.task_simulate(50.0, 50.0, 100, 20, 1)
# Out:
# [REPORT] 1(0.010) customers leave due to overflow of queue.
# [REPORT] average service process for served customers is 46.709689

# %%
# mean_arrive=50.0, mean_serve=50.0, num_custom=100, max_queue=20, num_service=1
a.task_simulate(50.0, 50.0, 100, 20, 1)
# Out:
# [REPORT] 1(0.010) customers leave due to overflow of queue.
# [REPORT] average service process for served customers is 47.199126

# %%
# mean_arrive=50.0, mean_serve=50.0, num_custom=100, max_queue=20, num_service=1
a.task_simulate(50.0, 50.0, 100, 20, 1)
# Out:
# [REPORT] 1(0.010) customers leave due to overflow of queue.
# [REPORT] average service process for served customers is 55.183555

# %%
# mean_arrive=50.0, mean_serve=100.0, num_custom=100, max_queue=10, num_service=3
a.task_simulate(50.0, 100.0, 100, 10, 3)
# Out:
# [REPORT] 1(0.010) customers leave due to overflow of queue.
# [REPORT] average service process for served customers is 92.430743

# %%
# 人流分布特点
x = np.random.poisson(lam=50.0, size=10000)  # lam为λ size为k
plt.hist(x)
plt.title("Poisson Distribution of Customers' Arrival Time")
plt.show()
