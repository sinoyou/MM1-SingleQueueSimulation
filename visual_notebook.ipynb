# %%
from main.preprocess import *

# %%
a = Global()

# %%
# mean_arrive=50.0, mean_serve=100.0, num_custom=100, max_queue=10, num_service=1
service_mean_list = np.arange(50.0, 100.0, 1)
a.task_parameter_of_service_mean(50.0, service_mean_list, 100, 10, 1)

# %%
# mean_arrive=50.0, mean_serve=100.0, num_custom=10000, max_queue=1000, num_service=1
service_mean_list = np.arange(50.0, 100.0, 1)
a.task_parameter_of_service_mean(50.0, service_mean_list, 10000, 1000, 1)

# %%
# mean_arrive=50.0, mean_serve=100.0, num_custom=100, max_queue=10, num_service=1
internal_mean_list = np.arange(50.0, 100.0, 1)
a.task_parameter_of_arrival_mean(service_mean_list, 100.0,100, 10, 1)

# %%
# mean_arrive=50.0, mean_serve=100.0, num_custom=10000, max_queue=1000, num_service=1
internal_mean_list = np.arange(50.0, 100.0, 1)
a.task_parameter_of_arrival_mean(service_mean_list, 100.0,10000, 1000, 1)

# %%
# mean_arrive=10.0, mean_serve=100.0, num_custom=100, max_queue=10, num_service=1
service_list = range(1,10,1)
a.task_parameter_of_service_num(10, 100.0,100, 10, service_list)

# %%
# mean_arrive=10.0, mean_serve=100.0, num_custom=10000, max_queue=1000, num_service=1
service_list = range(1,20,1)
a.task_parameter_of_service_num(10, 100.0,10000, 1000, service_list)

# %%
# mean_arrive=50.0, mean_serve=100.0, num_custom=100, max_queue=10, num_service=1
a.task_simulate(50.0, 100.0, 100, 15, 1)
# Out:
# [REPORT] 32(0.320) customers leave due to overflow of queue.
# [REPORT] average service process for served customers is 104.654861

# %%
# mean_arrive=50.0, mean_serve=100.0, num_custom=100, max_queue=10, num_service=3
a.task_simulate(50.0, 100.0, 100, 10, 3)
# Out:
# [REPORT] 1(0.010) customers leave due to overflow of queue.
# [REPORT] average service process for served customers is 92.430743
